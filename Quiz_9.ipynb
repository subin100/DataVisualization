# %% [markdown]
# <a href="https://colab.research.google.com/github/subin100/DataVisualization/blob/main/Quiz_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Subin Manandhar
# ##Instructor: Dr Nicholas Jacob
# ##Data Visualization
# ##Quiz 9

# %% [markdown]
# At first, Let's load the same wiki page of Marvel Cinematic Universe Film provided in the assignment.

# %%
import requests
import pandas as pa
from bs4 import BeautifulSoup


r = requests.get('https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films')
html_contents = r.text
html_soup = BeautifulSoup(html_contents,"lxml")

# %%
len(html_soup.find_all('table'))
# Out:
# 7

# %% [markdown]
# The output here shows that there are 7 tables stored in the list.
#
#
# Let's display the table before we start working with it.

# %%
tables = html_soup.find_all('table',class_="wikitable plainrowheaders")
df = pa.read_html(str(tables))[0]
df
# Out:
#                                    Film  ... Unnamed: 5_level_0
#                            Phase One[2]  ...       Phase One[2]
# 0                              Iron Man  ...                NaN
# 1                   The Incredible Hulk  ...                NaN
# 2                            Iron Man 2  ...                NaN
# 3                                  Thor  ...                NaN
# 4    Captain America: The First Avenger  ...                NaN
# 5                 Marvel's The Avengers  ...                NaN
# 6                          Phase Two[2]  ...       Phase Two[2]
# 7                            Iron Man 3  ...                NaN
# 8                  Thor: The Dark World  ...                NaN
# 9   Captain America: The Winter Soldier  ...                NaN
# 10              Guardians of the Galaxy  ...                NaN
# 11              Avengers: Age of Ultron  ...                NaN
# 12                              Ant-Man  ...                NaN
# ...

# %% [markdown]
# The table is pretty rough here, like unnecessary column names are displayed here. And also there are some phases listed in the middle of the table.
#
# First let's fix the column names.

# %%
titles = []
titles.append('Film')
titles.append('Release Date')
titles.append('Directors')
titles.append('Screenwriters')


for name in data[0]:
  titles.append('Producer')
titles.append('Process')

df = pa.DataFrame(data[2:], columns = titles)
df
# Out:
#                                                  Film  ...          Process
# 0                                 The Incredible Hulk  ...             None
# 1                                          Iron Man 2  ...             None
# 2                                                Thor  ...             None
# 3                  Captain America: The First Avenger  ...             None
# 4                               Marvel's The Avengers  ...             None
# 5                                        Phase Two[2]  ...             None
# 6                                          Iron Man 3  ...             None
# 7                                Thor: The Dark World  ...             None
# 8                 Captain America: The Winter Soldier  ...             None
# 9                             Guardians of the Galaxy  ...             None
# 10                            Avengers: Age of Ultron  ...             None
# ...

# %% [markdown]
# This is much better. Here I gave name for the each columns. It looks much better than the table that we printed before.

# %% [markdown]
# Like I said above there are some unnecessarily phases listed in row 5 and 12, so let's go ahead and remove those from the table

# %%
df = df.drop(df.index[[5,12]])
df
# Out:
#                                    Film  ... Unnamed: 5_level_0
#                            Phase One[2]  ...       Phase One[2]
# 0                              Iron Man  ...                NaN
# 1                   The Incredible Hulk  ...                NaN
# 2                            Iron Man 2  ...                NaN
# 3                                  Thor  ...                NaN
# 4    Captain America: The First Avenger  ...                NaN
# 6                          Phase Two[2]  ...       Phase Two[2]
# 7                            Iron Man 3  ...                NaN
# 8                  Thor: The Dark World  ...                NaN
# 9   Captain America: The Winter Soldier  ...                NaN
# 10              Guardians of the Galaxy  ...                NaN
# 11              Avengers: Age of Ultron  ...                NaN
# 13                       Phase Three[2]  ...     Phase Three[2]
# 14           Captain America: Civil War  ...                NaN
# ...

# %% [markdown]
# Hence the unnecessary rows are deleted from the table and now the table looks clean.
