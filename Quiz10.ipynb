# %% [markdown]
# <a href="https://colab.research.google.com/github/subin100/DataVisualization/blob/main/Quiz10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Subin Manandhar
# ###Instructor: Dr Nicholas Jacob
# ###Quiz10

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pa

url = "https://fbref.com/en/squads/18bb7c10/Arsenal-Stats"

r = requests.get(url)
soup = BeautifulSoup(r.text)

tables = soup.find_all('table')

pa.read_html(str(tables[0]))[0]
# Out:
#            Unnamed: 0_level_0 Unnamed: 1_level_0  ... Per 90 Minutes Unnamed: 29_level_0
#                        Player             Nation  ...        npxG+xA             Matches
# 0                   Ben White            eng ENG  ...           0.02             Matches
# 1                 Bukayo Saka            eng ENG  ...           0.45             Matches
# 2              Aaron Ramsdale            eng ENG  ...           0.00             Matches
# 3          Gabriel Dos Santos             br BRA  ...           0.07             Matches
# 4           Takehiro Tomiyasu             jp JPN  ...           0.06             Matches
# 5               Thomas Partey             gh GHA  ...           0.15             Matches
# 6             Martin Ødegaard             no NOR  ...           0.37             Matches
# 7              Kieran Tierney            sct SCO  ...           0.13             Matches
# ...

# %% [markdown]
# Sorry professor, I had to do the Arsenal stat after I saw a spurs stat.
